# %%
import pandas as pd

df = pd.read_csv("/home/nkk/Área de trabalho/projetos/IC/src/ic/dates/teste16_10_001.csv")
df
# Out:
#              timestamp    CPS    CPM  uSv/h   mR/h
# 0  2025-10-16 20:04:28  2.017  121.0  0.787  0.079
# 1  2025-10-16 20:05:28  1.817  109.0  0.709  0.071
# 2  2025-10-16 20:06:28  2.033  122.0  0.793  0.079
# 3  2025-10-16 20:07:28  1.917  115.0  0.748  0.075
# 4  2025-10-16 20:08:28  2.167  130.0  0.845  0.085
# 5  2025-10-16 20:09:28  2.150  129.0  0.839  0.084
# 6  2025-10-16 20:10:28  2.117  127.0  0.826  0.083

# %%
df['CPM'].mean()
# Out:
# np.float64(121.85714285714286)
